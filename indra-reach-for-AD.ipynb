# %%
from indra.tools.gene_network import GeneNetwork
from indra import literature
from indra.sources import reach
from indra.tools import assemble_corpus as ac

from libsbml import *

# ['APOE', 'MAPT']

gn = GeneNetwork(['APOE'])
biopax_stmts = gn.get_biopax_stmts()
bel_stmts = gn.get_bel_stmts()
# Out:
# WARNING: [2021-09-25 22:53:24] indra.sources.reach.api - Could not import jnius, offline reading option will not be available.
# WARNING: [2021-09-25 22:53:24] indra.tools.gene_network - Using neighborhood query for one gene.
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client - Sending Pathway Commons query with parameters:
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  format: BIOPAX
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  organism: 9606
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  datasource: None
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  kind: neighborhood
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  source: APOE
# INFO: [2021-09-25 22:53:24] pybiopax.pc_client -  limit: 1
# Processing OWL elements: 100%|█████████| 98147/98147 [00:08<00:00, 11252.68it/s]
# INFO: [2021-09-25 22:53:41] indra.ontology.bio.ontology - Loading INDRA bio ontology from cache at /home/smalec/.indra/bio_ontology/1.12/bio_ontology.pkl
# INFO: [2021-09-25 22:53:52] indra.sources.bel.api - Loading https://github.com/cthoyt/selventa-knowledge/raw/v1.0.0/selventa_knowledge/large_corpus.bel.nodelink.json.gz
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Adssl1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Adssl1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Them7)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:4833439L19Rik)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hist1h2bc)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:H13)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Txn1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:A830073O21Rik)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cd24a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ppap2c)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Atp5b)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fh1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Abcb1b)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:G6pd)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hrc)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Atpif1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:D17H6S56E-5)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Muc5ac)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fasl)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fasl)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Srxn1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mdm2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slc7a11)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Smad6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Smad6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Klf4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Klf4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ccna2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cdkn1a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Osgin1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Bcl2l2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Bnip3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Csnk2a2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cdc6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gltscr2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hsf1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mtch1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Supt4h1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ube2j1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Abi2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atm)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atp5d)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Bik)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cct7)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Dyrk2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Npas2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Phka2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pycard)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Plagl1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Psmd3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tp53bp2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gltscr2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp51)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Mapk11)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Stx4a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Car3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Nr2f1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: GUCY1 Complex (complex(SCOMP:"GUCY1 Complex"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tln1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: Respiratory Chain Complex IV (complex(SCOMP:"Respiratory Chain Complex IV"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: Respiratory Chain Complex IV (complex(SCOMP:"Respiratory Chain Complex IV"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: Respiratory Chain Complex IV (complex(SCOMP:"Respiratory Chain Complex IV"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ctgf)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Itgav)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1a3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - HGNC entity CKS1BP7 with HGNC ID 1999 has no corresponding Uniprot ID.
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Myh2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:G6pd)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Mapkapk2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Stat1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Hsf1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fasl)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fasl)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Btk)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: Respiratory Chain Complex IV (complex(SCOMP:"Respiratory Chain Complex IV"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Brf1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Lcn1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:H2-Eb2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - No Uniprot ID for HGNC ID 9589
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hdgfrp2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Zfp688)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Mt-co2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mt-co2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ctgf)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Bmyc)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Bmyc)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ahnak)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:C4b)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4v3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Dhrs3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Dnaja4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ifngr1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Inmt)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Irf7)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mkrn1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ptpn18)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slpi)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sec23b)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Akr7a5)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fam132a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Myom2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Myom2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Thbs1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ppap2a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Aes)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gpi1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hoxb13)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ttn)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fcer2a)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Ifngr2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:2810417H13Rik)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Apitd1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:BC046251)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: PP2A Complex (complex(SCOMP:"PP2A Complex"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: PP2A Complex (complex(SCOMP:"PP2A Complex"))
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - No Uniprot ID for HGNC ID 4660
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Fasl)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pira5)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pla2g16)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:H2afy)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Igf2r)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mst1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Rfc1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sepw1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tceb2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ybx1-ps3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:C1r)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Prodh)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Herpud1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ugt1a7c)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hes6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Vtn)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:"Cyp3a23/3a1")
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sult2a6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Ccr7)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:F5)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Saa4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Slc37a4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp2c22)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a3)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a8)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RGD1565355)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slc25a14)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Abcc4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Abcc4)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Trp53)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Tcirg1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Nat6)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ptprd)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Psat1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Col5a2)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Lad1)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Aars)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Aars)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Cd40)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cyp51)
# INFO: [2021-09-25 22:54:14] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Zfa-ps)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Rdx)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cited2)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:D15Ertd621e)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cdkn1b)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: Ngf Complex (complex(SCOMP:"Ngf Complex"))
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:H2afx)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Abcc4)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:"Cyp3a23/3a1")
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gstt3)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mgst2)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyr61)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Gucy1a3)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1a3)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - No Uniprot ID for HGNC ID 11636
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - No Uniprot ID for HGNC ID 5865
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Enc1)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ctgf)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ccrn4l)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pfkfb3)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:G6pd)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Tnxb)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Akr1c19)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - More than one current HGNC ID for QARS, choosing 3418
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hao1)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tnc)
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Could not find GO ID for single organismal cell-cell adhesion
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"single organismal cell-cell adhesion")
# INFO: [2021-09-25 22:54:15] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cybb)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Dut)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Dut)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Eef1b2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Sgol1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ccl17)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ccl17)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fcer2a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ccl12)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Mpo)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pfkfb3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pfkfb3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pfkfb3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Irs2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:PVR)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tnfaip6)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Ccl17)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Muc5ac)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: m(MGI:Mir155)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: m(MGI:Mir155)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - No Uniprot ID for HGNC ID 31542
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Agpat6)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gpi1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Zbtb16)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ascc1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Art3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ctgf)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cxcl12)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cdadc1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ddrgk1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fat1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fbn1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fnbp4)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hells)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hiatl1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Itga6)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Lgi3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Lrrc43)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mrpl4)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mfap5)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ogn)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pmepa1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pnn)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Paip2l1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ppp1r16a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RGD1308706)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Rtf1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sppl2a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Stoml1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tmem68)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Champ1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atp5a1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ddx51)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Erp27)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hist1h2bh)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hist1h2bj)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hist1h2bl)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hist3h2a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Kpna3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mrpl49)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ns5atp9)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Prrx2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Reg1a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RGD1311703)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Serinc3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:St6galnac2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sf3b1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sult1c3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tspan7)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ank)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pfkfb3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fam65b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:G6pd)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Akr1c1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Cdkn1b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Olfr166)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Gyk)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Idh3b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Idh3b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Idh3b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Agpat6)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cacna1g)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cacna1g)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ccl27a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hist1h1c)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hist1h1c)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Zfp354a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Zfp354a)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:1700008B15Rik)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Myh2)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sep15)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Txn1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Akr1c1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Car3)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Egfr)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ctgf)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Ctgf)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Prkg1)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fcrls)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pomp)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Clec4n)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Muc5b)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pirb)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pirb)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Tmem173)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Tmem173)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Btc)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Btc)
# INFO: [2021-09-25 22:54:17] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Btc)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ank)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Il4ra)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Btc)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Mylk)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Trf)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gyg)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Sepp1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Plagl1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Gucy1a3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1a3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gucy1b3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Dfna5)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Dctn3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mllt4)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Nnt)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fam217b)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slc25a10)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slc25a10)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ccrn4l)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Dars)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Eif1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Npepps)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Psme3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Psmd14)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Stau1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Rpo1-3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atf1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gtf2e2)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Gtf2ird1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Qk)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ryk)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Suv39h1l1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Sars)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Sept4)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Yars)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:6720489N17Rik)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Bms1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Skp1a)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Tmem27)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Adipor1)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Acss2)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Adipor2)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pnpla3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:G6pd)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find GO ID for glucose transport
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: bp(GOBP:"glucose transport")
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp51)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Sp3)
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: PP2A Complex (complex(SCOMP:"PP2A Complex"))
# INFO: [2021-09-25 22:54:18] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:B3gnt2)
# ...
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Trp53)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Hrsp12)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Vnn1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: ATP Dependent Potassium Channel Complex (complex(SCOMP:"ATP Dependent Potassium Channel Complex"))
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mbd3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mbd1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cyr61)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cd24a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gdap10)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Il4ra)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Slfn4)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ube2j1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fcgr2a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fcgr2a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RT1-A1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RT1-A2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Nfib)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:H6pd)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Col5a2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Col5a3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ltbp3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:G6pd)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ero1lb)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ern1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Atp5b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atp5b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atp5h-ps1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:H3f3b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ncoa4)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcx)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Reg3d)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Sepp1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Txn1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Wbp5)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Chil1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Muc5ac)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Muc5ac)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Muc5ac)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Muc5ac)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ugt1a6a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(MGI:Trp53)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Bcl2a1a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fcgr2b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Fcgr2b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ifi47)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ifi47)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ngfrap1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ngfrap1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Igf2r)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Col4a1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Col4a2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Ddr2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ddr2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Car3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Aldoart1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cyp2b13)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Hba-a1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Tars)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cd24a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Col5a3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Col4a5)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:C1qtnf2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:C1qtnf2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:C1qtnf7)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Foxo3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Vsig4)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Defa5)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Higd2a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Irf3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:RGD1310209)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Serpina4)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Slc37a4)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:"Cyp3a23/3a1")
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp4a3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cyp51)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:ste2)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:C530047H08Rik)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Itpkb)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Iars)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Could not find mapping for BEL/SCOMP complex: ATP Dependent Potassium Channel Complex (complex(SCOMP:"ATP Dependent Potassium Channel Complex"))
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pth)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Nov)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cyr61)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Foxo3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - No Uniprot ID for HGNC ID 4660
# WARNING: [2021-09-25 22:54:25] indra.sources.bel.processor - More than one "Species" in annotations
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: p(RGD:Vtn)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ptpn13)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Atp5h-ps1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mt-cox3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Prkcdbp)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Psma3l)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Mt-co1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ptpro)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ccbl1)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fcgr2a)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Fcgr2b)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Sfpq)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Aes)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Bhlhe41)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Lre3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Nfix)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Obp3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Pla2g16)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Tspan8)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Ptprd)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gbp3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gbp3)
# INFO: [2021-09-25 22:54:25] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Gbp6)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ugt8a)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:March7)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Pcdh7)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - HGNC entity TCAM1P with HGNC ID 30707 has no corresponding Uniprot ID.
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ifi205)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ifi47)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Txn1)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cybb)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Ctgf)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(MGI:Cyr61)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Unable to get identifier information for node: r(RGD:Cradd)
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data
# INFO: [2021-09-25 22:54:26] indra.sources.bel.processor - Nodes of type Reaction not handled: No node data

# %%
pmids = literature.pubmed_client.get_ids_for_gene('APOE')

paper_contents = {}
for pmid in pmids:
    content, content_type = literature.get_full_text(pmid, 'pmid')
    if content_type == 'abstract':
        paper_contents[pmid] = content
    if len(paper_contents) == 10:
        break

literature_stmts = []
for pmid, content in paper_contents.items():
    rp = reach.process_text(content, url=reach.local_text_url)
    literature_stmts += rp.statements
print('Got %d statements' % len(literature_stmts))
# Out:
# INFO: [2021-09-25 22:54:48] indra.literature - Elsevier: 27329241
# ERROR: [2021-09-25 22:54:48] indra.literature.elsevier_client - Could not download article https://api.elsevier.com/content/article/doi/10.1016/j.neulet.2016.06.032: status code 401
# ERROR: [2021-09-25 22:54:48] indra.literature.elsevier_client - Elsevier response: {"error-response":{"error-code":"APIKEY_INVALID","error-message":"The provided apiKey is invalid."}}
# WARNING: [2021-09-25 22:54:50] indra.literature.pmc_client - PMC client returned with error cannotDisseminateFormat: The metadata format 'pmc' is not supported by the item or by the repository.
# INFO: [2021-09-25 22:54:53] indra.literature - Elsevier: 29858039
# ERROR: [2021-09-25 22:54:53] indra.literature.elsevier_client - Could not download article https://api.elsevier.com/content/article/doi/10.1016/j.neurobiolaging.2018.04.013: status code 401
# ERROR: [2021-09-25 22:54:53] indra.literature.elsevier_client - Elsevier response: {"error-response":{"error-code":"APIKEY_INVALID","error-message":"The provided apiKey is invalid."}}
# INFO: [2021-09-25 22:54:56] indra.literature - Elsevier: 17941342
# ERROR: [2021-09-25 22:54:56] indra.literature.elsevier_client - Could not download article https://api.elsevier.com/content/article/doi/10.1016/s0010-9452(08)70683-x: status code 401
# ERROR: [2021-09-25 22:54:56] indra.literature.elsevier_client - Elsevier response: {"error-response":{"error-code":"APIKEY_INVALID","error-message":"The provided apiKey is invalid."}}
# WARNING: [2021-09-25 22:55:02] indra.literature.pmc_client - PMC client returned with error cannotDisseminateFormat: The metadata format 'pmc' is not supported by the item or by the repository.
# ERROR: [2021-09-25 22:55:22] indra.sources.reach.api - Could not decode JSON string.
# ERROR: [2021-09-25 22:55:22] indra.sources.reach.api - Expecting value: line 1 column 1 (char 0)
# Traceback (most recent call last):
#   File "/home/smalec/.local/lib/python3.8/site-packages/indra/sources/reach/api.py", line 397, in process_json_str
#     json_dict = json.loads(json_str)
#   File "/usr/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_582196/166475087.py in <module>
#      12 for pmid, content in paper_contents.items():
#      13     rp = reach.process_text(content, url=reach.local_text_url)
# ---> 14     literature_stmts += rp.statements
#      15 print('Got %d statements' % len(literature_stmts))
#
# AttributeError: 'NoneType' object has no attribute 'statements'

# %%
stmts = bel_stmts + biopax_stmts + literature_stmts

stmts = ac.map_grounding(stmts)
stmts = ac.map_sequence(stmts)
stmts = ac.run_preassembly(stmts)

# Assemble the statements into a network model

from indra.assemblers.pysb import PysbAssembler

pa = PysbAssembler()
pa.add_statements(stmts)
model = pa.make_model()

# Compile model

import os
os.environ['BNGPATH'] = '/home/smalec/Projects/BioNetGen-2.6.0'

for monomer in pa.model.monomers:
    print(monomer)

for rule in pa.model.rules:
    print(rule)


for annotation in pa.model.annotations:
    print(annotation)




pa.export_model('sbml', file_name='model.sbml')
# Out:
# INFO: [2021-09-25 22:57:56] indra.preassembler.grounding_mapper.disambiguate - INDRA DB is not available for text content retrieval for grounding disambiguation.
# INFO: [2021-09-25 22:57:56] indra.tools.assemble_corpus - Mapping grounding on 1469 statements...
# INFO: [2021-09-25 22:57:56] indra.preassembler.grounding_mapper.disambiguate - INDRA DB is not available for text content retrieval for grounding disambiguation.
# INFO: [2021-09-25 22:57:56] indra.preassembler.grounding_mapper.mapper - 0 statements filtered out
# INFO: [2021-09-25 22:57:56] indra.tools.assemble_corpus - Mapping sites on 1469 statements...
# INFO: [2021-09-25 22:57:56] protmapper.uniprot_client - Loading Swissprot sequences...
# INFO: [2021-09-25 22:57:58] protmapper.uniprot_client - Loading Uniprot isoform sequences...
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - 1469 statements with valid sites
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - Combining duplicates on 1469 statements...
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - 836 unique statements
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - Combining related on 836 statements...
# Finding refinement relations: 100%|█████████| 836/836 [00:00<00:00, 3995.21it/s]
# INFO: [2021-09-25 22:57:59] indra.preassembler - Found all refinements in 0.24s
# INFO: [2021-09-25 22:57:59] indra.preassembler - Total comparisons: 58
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - Filtering 836 statements for top-level...
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - 807 statements after filter...
# INFO: [2021-09-25 22:57:59] indra.tools.assemble_corpus - 807 top-level statements
# INFO: [2021-09-25 22:58:00] indra.assemblers.pysb.assembler - Using default assembly policy.
# WARNING: [2021-09-25 22:58:00] indra.databases.identifiers - Unhandled name space SDIS
# WARNING: [2021-09-25 22:58:00] indra.databases.identifiers - Unhandled name space SDIS
# WARNING: [2021-09-25 22:58:00] indra.assemblers.pysb.assembler - VEGFA transcribes itself, skipping
# Monomer('LSR', ['apolipoprotein'])
# Monomer('AD', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('APOE', ['lsr', 'lrp1', 'activity', 'S314'], {'activity': ['inactive', 'active'], 'S314': ['u', 'p']})
# Monomer('tumor_cell_invasion', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('endocytosis', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('cell_cycle', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('LRP1', ['apolipoprotein'])
# Monomer('Oxidized_High_Density_Lipoprotein')
# Monomer('hsa_miR_1908_5p')
# Monomer('hsa_miR_199a_3p')
# Monomer('hsa_miR_199a_5p')
# Monomer('zearalenone')
# Monomer('VEGFA')
# Monomer('disodium_selenite_pentahydrate')
# Monomer('PON2')
# Monomer('tyrphostin_B42')
# Monomer('meclocycline')
# Monomer('lanatoside_C')
# Monomer('ethylisopropylamiloride')
# Monomer('JQ1')
# Monomer('all_trans_retinoic_acid')
# Monomer('CHRM2')
# Monomer('MT2A')
# Monomer('hexadecanoic_acid')
# Monomer('juglone')
# Monomer('luteolin')
# Monomer('palmatine')
# Monomer('DDT')
# Monomer('oleic_acid')
# Monomer('hydrogen_peroxide')
# Monomer('p17beta_hydroxy_5alpha_androstan_3_one')
# Monomer('triclosan')
# Monomer('bilirubin_IXalpha')
# Monomer('p2_methylcholine')
# Monomer('glucose')
# Monomer('cortisol')
# Monomer('calcitriol')
# Monomer('puromycin')
# Monomer('apigenin')
# Monomer('_2_4_dichlorophenoxy_acetate')
# Monomer('acetylcysteine')
# Monomer('Antimycin_A')
# Monomer('ascorbic_acid')
# Monomer('copper_II__sulfate')
# Monomer('estradiol')
# Monomer('ACHE')
# Monomer('lead_atom')
# Monomer('aflatoxin_B1')
# Monomer('methyl_methanesulfonate')
# Monomer('polyphenol')
# Monomer('zinc_atom')
# Monomer('folic_acid')
# Monomer('arsenic_atom')
# Monomer('selenium_atom')
# Monomer('cobalt_atom')
# Monomer('camptothecin')
# Monomer('oxytetracycline')
# Monomer('paraoxon')
# Monomer('chloroacetaldehyde')
# Monomer('resveratrol')
# Monomer('cisplatin')
# Monomer('parathion')
# Monomer('genistein')
# Monomer('nickel_atom')
# Monomer('p2_3_7_8_tetrachlorodibenzodioxine')
# Monomer('methylmercury_chloride')
# Monomer('rutin')
# Monomer('cytarabine')
# Monomer('doxorubicin')
# Monomer('flavanones')
# Monomer('p2_methoxy_17beta_estradiol')
# Monomer('sodium_arsenite')
# Monomer('tunicamycin')
# Monomer('baicalein')
# Monomer('benzo_a_pyrene')
# Monomer('beclomethasone')
# Monomer('silicon_dioxide')
# Monomer('gallic_acid')
# Monomer('betamethasone')
# Monomer('alclometasone_dipropionate')
# Monomer('benzethonium_chloride')
# Monomer('oxaliplatin')
# Monomer('Proscillaridin')
# Monomer('budesonide')
# Monomer('butein')
# Monomer('chromium_6__')
# Monomer('bisphenol_A')
# Monomer('vitamin_E')
# Monomer('candesartan')
# Monomer('tungsten_molecular_entity')
# Monomer('capsaicin')
# Monomer('____anisomycin')
# Monomer('carbamazepine')
# Monomer('p2_2__5_5__tetrachlorobiphenyl')
# Monomer('p4_4__sulfonyldiphenol')
# Monomer('quinomethionate')
# Monomer('p3_isobutyl_1_methyl_7H_xanthine')
# Monomer('tris_2_butoxyethyl__phosphate')
# Monomer('cadmium_dichloride')
# Monomer('cerium_trichloride')
# Monomer('cobalt_dichloride')
# Monomer('Chebulinic_acid')
# Monomer('phorbol_13_acetate_12_myristate')
# Monomer('phosphorus_31_atom')
# Monomer('dicrotophos')
# Monomer('coumestrol')
# Monomer('chloropicrin')
# Monomer('atorvastatin')
# Monomer('curcumin')
# Monomer('valproic_acid')
# Monomer('cyclophosphamide')
# Monomer('cyclosporin_A')
# Monomer('celecoxib')
# Monomer('dequalinium')
# Monomer('dexamethasone')
# Monomer('daunorubicin')
# Monomer('digoxigenin')
# Monomer('digitoxigenin')
# Monomer('emodin')
# Monomer('Deguelin')
# Monomer('obeticholic_acid')
# Monomer('indirubin_3__monoxime')
# Monomer('____demecolcine')
# Monomer('methotrexate')
# Monomer('nimesulide')
# Monomer('desogestrel')
# Monomer('digoxin')
# Monomer('vorinostat')
# Monomer('TAXOTERE')
# Monomer('paracetamol')
# Monomer('p5_fluorouracil')
# Monomer('dipyridamole')
# Monomer('isobutanol')
# Monomer('crocidolite_asbestos')
# Monomer('doxazosin')
# Monomer('alvocidib')
# Monomer('diclofenac')
# Monomer('bezafibrate')
# Monomer('embelin')
# Monomer('emetine')
# Monomer('methionine_sulfoximine')
# Monomer('enalapril')
# Monomer('lithium_chloride')
# Monomer('copper_II__chloride')
# Monomer('indometacin')
# Monomer('arsenous_acid')
# Monomer('rosiglitazone')
# Monomer('p5_aza_2__deoxycytidine')
# Monomer('motexafin_gadolinium')
# Monomer('mifepristone')
# Monomer('minocycline')
# Monomer('fludrocortisone')
# Monomer('propidium')
# Monomer('bufalin')
# Monomer('lithium_7_atom')
# Monomer('bortezomib')
# Monomer('Genipin')
# Monomer('nickel_sulfate')
# Monomer('potassium_dichromate')
# Monomer('cobalt_2___sulfate')
# Monomer('alexidine')
# Monomer('glucosamine')
# Monomer('Honokiol')
# Monomer('cetrorelix')
# Monomer('romidepsin')
# Monomer('canertinib')
# Monomer('zinc_acetate')
# Monomer('potassium_nitrate')
# Monomer('ribavirin')
# Monomer('nevirapine')
# Monomer('topotecan')
# Monomer('zerumbone')
# Monomer('tert_butyl_hydroperoxide')
# Monomer('p8_bromo_3__5__cyclic_GMP')
# Monomer('N_methyl_4_phenylpyridinium')
# Monomer('p4_____5_5_8_8_tetramethyl_5_6_7_8_tetrahydronaphthalen_2_yl_carbonyl_amino__benzoic_acid')
# Monomer('ciglitazone')
# Monomer('LY294002')
# Monomer('andrographolide')
# Monomer('losartan')
# Monomer('demethoxycurcumin')
# Monomer('lycorine')
# Monomer('Delta_9__tetrahydrocannabinol')
# Monomer('melittin')
# Monomer('metformin')
# Monomer('metoprolol')
# Monomer('withaferin_A')
# Monomer('GW_7647')
# Monomer('triamcinolone_acetonide')
# Monomer('ICI_118551')
# Monomer('WIN_55212_2')
# Monomer('p5_chloro_7_iodoquinolin_8_ol')
# Monomer('carbonyl_cyanide_p_trifluoromethoxyphenylhydrazone')
# Monomer('niclosamide')
# Monomer('sarin')
# Monomer('ochratoxin_A')
# Monomer('octreotide')
# Monomer('p2__2_amino_3_methoxyphenyl_chromen_4_one')
# Monomer('diallyl_trisulfide')
# Monomer('Nonidet_P_40')
# Monomer('paricalcitol')
# Monomer('Nonylphenol')
# Monomer('Temsirolimus')
# Monomer('GW_4064')
# Monomer('Salinomycin')
# Monomer('phenobarbital')
# Monomer('Enterolactone')
# Monomer('Tungsten_carbide')
# Monomer('piroxicam')
# Monomer('icariside_II')
# Monomer('propranolol')
# Monomer('iron_trichloride_hexahydrate')
# Monomer('pyrvinium')
# Monomer('N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine')
# Monomer('Rhein')
# Monomer('SB_203580')
# Monomer('semaxanib')
# Monomer('simvastatin')
# Monomer('sirolimus')
# Monomer('testosterone_enanthate')
# Monomer('dimethyl__phenylmethyl___2__2__4__2_4_4_trimethylpentan_2_yl_phenoxy_ethoxy_ethyl_ammonium')
# Monomer('thalidomide')
# Monomer('thapsigargin')
# Monomer('thimerosal')
# Monomer('valsartan')
# Monomer('SOD2')
# Monomer('SP1')
# Monomer('TEAD1')
# Monomer('ZNF202')
# Monomer('E2F1')
# Monomer('AGT')
# Monomer('GATA3')
# Monomer('HIF1A')
# Monomer('HOXA4')
# Monomer('IFNG')
# Monomer('IL6')
# Monomer('INS')
# Monomer('Oxidized_Low_Density_Lipoprotein')
# Monomer('reactive_oxygen_species')
# Monomer('PIK3CA')
# Monomer('PPARA')
# Monomer('Drupanin')
# Monomer('coralyne')
# Monomer('potassium_perchlorate')
# Monomer('O_O_diethyl_O_3_5_6_trichloro_2_pyridyl_phosphate')
# Monomer('fludarabine')
# Monomer('tobacco_tar')
# Monomer('heat_stable_toxin__E_coli_')
# Monomer('N__deoxyguanosin_8_yl__1_aminopyrene')
# Monomer('epigallocatechin_gallate')
# Monomer('S_1_2_dichlorovinyl_N_acetylcysteine')
# Monomer('p4_hydroxy_equilenin')
# Monomer('norcantharidin')
# Monomer('seocalcitol')
# Monomer('Coptidis_rhizoma_extract')
# Monomer('acyline')
# Monomer('p15_16_dihydrotanshinone_I')
# Monomer('K_7174')
# Monomer('_E__4___2_N__4_methoxybenzenesulfonyl_amino_stilbazole_1_oxide')
# Monomer('p103D5R')
# Monomer('Grape_Seed_Proanthocyanidins')
# Monomer('ganoderic_acid_A')
# Monomer('auriculasin')
# Monomer('N___11H_indolo_3_2_c_quinolin_6_yl__N_N_dimethylethane_1_2_diamine')
# Monomer('punarnavine')
# Monomer('jinfukang')
# Monomer('molibresib')
# Monomer('GSK1210151A')
# Monomer('p2_amino_8__4__2_hydroxyethoxy_cyclohexyl__6__6_methoxypyridin_3_yl__4_methylpyrido_2_3_d_pyrimidin_7_8H__one')
# Monomer('C646_compound')
# Monomer('Meglumine_Antimoniate')
# Monomer('Aerosols')
# Monomer('Air_Pollutants__Occupational')
# Monomer('Vehicle_Emissions')
# Monomer('Chrysenes')
# Monomer('Dietary_Fats')
# Monomer('Dust')
# Monomer('Gasoline')
# Monomer('Plant_Extracts')
# Monomer('Strophanthins')
# Monomer('Tobacco_Smoke_Pollution')
# Monomer('Uranium_Compounds')
# Monomer('Arsenites')
# Monomer('Ciglitazone')
# Monomer('zidovudine')
# Monomer('entinostat')
# Monomer('lysophosphatidic_acid')
# Monomer('avobenzone')
# Monomer('Azaspiracid')
# Monomer('dinophysistoxin_1')
# Monomer('acrolein')
# Monomer('staurosporine')
# Monomer('butanal')
# Monomer('arachidonic_acid')
# Monomer('atrazine')
# Monomer('cholesterol')
# Monomer('ethanol')
# Monomer('quercetin')
# Monomer('adenosine')
# Monomer('lipopolysaccharide')
# Monomer('albendazole')
# Monomer('benzo_d_isothiazol_3_one')
# Monomer('formaldehyde')
# Monomer('progesterone')
# Monomer('fluoride')
# Monomer('propanal')
# Monomer('cinnamyl_alcohol')
# Monomer('biochanin_A')
# Monomer('gemcitabine')
# Monomer('glycerol')
# Monomer('p4_methylumbelliferyl_acetate')
# Monomer('urethane')
# Monomer('iron_atom')
# Monomer('manganese_atom')
# Monomer('vanillin')
# Monomer('nicotine')
# Monomer('p12_HETE')
# Monomer('cadmium_atom')
# Monomer('citral')
# Monomer('quinolone')
# Monomer('farnesal')
# Monomer('hexachlorocyclohexane')
# Monomer('bis_2_chloroethyl__sulfide')
# Monomer('p7_12_dimethyltetraphene')
# Monomer('naphthoquinone')
# Monomer('ozone')
# Monomer('amiodarone')
# Monomer('sodium_chloride')
# Monomer('trinitrotoluene')
# Monomer('uranium_atom')
# Monomer('genistein_7_O_beta_D_glucoside')
# Monomer('dipotassium_bis_mu_tartrato_4___diantimonate_2___trihydrate')
# Monomer('cycloheximide')
# Monomer('phenylmercury_acetate')
# Monomer('chromium_atom')
# Monomer('daidzein')
# Monomer('rotenone')
# Monomer('aristolochic_acid')
# Monomer('nornicotine')
# Monomer('p_chloromercuribenzoic_acid')
# Monomer('vincristine')
# Monomer('kaempferol')
# Monomer('oxidonitrogen_1__')
# Monomer('arsenite_3__')
# Monomer('divanadium_pentaoxide')
# Monomer('gold_0_')
# Monomer('copper_0_')
# Monomer('alpha_aluminium_oxide')
# Monomer('p2_2__bipyridine')
# Monomer('silver_atom')
# Monomer('vanadium_oxoanion')
# Monomer('DL_Isoprenaline_hydrochloride')
# Monomer('lead_diacetate')
# Monomer('gadopentetate_dimeglumine')
# Monomer('mercury_dichloride')
# Monomer('zinc_pyrithione')
# Monomer('silver_1___nitrate')
# Monomer('tamibarotene')
# Monomer('Calcimycin')
# Monomer('platinum')
# Monomer('oxygen_16_atom')
# Monomer('p1_1_1_Trichloro_2__o_chlorophenyl__2__p_chlorophenyl_ethane')
# Monomer('p1_3_benzothiazole_2_thiol')
# Monomer('p3_3__4_4__5_pentachlorobiphenyl')
# Monomer('p3_methylcholanthrene')
# Monomer('chlorpyrifos')
# Monomer('dibutyl_phthalate')
# Monomer('p1_chloro_2_4_dinitrobenzene')
# Monomer('mibolerone')
# Monomer('N_nitrosodiethylamine')
# Monomer('nickel_dichloride')
# Monomer('nocodazole')
# Monomer('paraquat')
# Monomer('zinc_sulfate')
# Monomer('perfluorooctanoic_acid')
# Monomer('dibenzo_a_l_pyrene')
# Monomer('chlorpromazine')
# Monomer('gadolinium_trichloride')
# Monomer('gadodiamide')
# Monomer('fluorescein_5_isothiocyanate')
# Monomer('iron_chelator')
# Monomer('fluvastatin')
# Monomer('sunitinib')
# Monomer('amitrole')
# Monomer('diethylstilbestrol')
# Monomer('dacarbazine')
# Monomer('afimoxifene')
# Monomer('p1_10_phenanthroline')
# Monomer('paclitaxel')
# Monomer('zoledronic_acid')
# Monomer('disulfiram')
# Monomer('tremolite_asbestos')
# Monomer('amphibole_asbestos')
# Monomer('quartz')
# Monomer('endosulfan')
# Monomer('brefeldin_A')
# Monomer('p17alpha_ethynylestradiol')
# Monomer('mercury_dibromide')
# Monomer('zinc_dichloride')
# Monomer('bucladesine')
# Monomer('cadmium_sulfate')
# Monomer('desferrioxamine')
# Monomer('carbon_nanotube')
# Monomer('N_acetyl_D_glucosamine')
# Monomer('p9_cis_retinoic_acid')
# Monomer('raloxifene_hydrochloride')
# Monomer('magnetite_nanoparticle')
# Monomer('p1_4_phenylenediamine')
# Monomer('methyl_non_2_ynoate')
# Monomer('imidurea')
# Monomer('cidofovir_2__')
# Monomer('diphenylcyclopropenone')
# Monomer('hydroxycitronellal')
# Monomer('N_formyl_L_methionyl_L_leucyl_L_phenylalanine')
# Monomer('toluene_2_4_diisocyanate')
# Monomer('chloromethylisothiazolinone')
# Monomer('alpha_hexylcinnamaldehyde')
# Monomer('p4_methylaminophenol_sulfate')
# Monomer('ifosfamide')
# Monomer('prostaglandin_E2_1__')
# Monomer('isotretinoin')
# Monomer('kaempferide')
# Monomer('p4_hydroxy_17beta_estradiol')
# Monomer('manganese_II__chloride')
# Monomer('succimer')
# Monomer('lansoprazole')
# Monomer('menadione_sodium_sulfonate')
# Monomer('arsenic_trichloride')
# Monomer('leflunomide')
# Monomer('p8_Br_cAMP')
# Monomer('p7_ketocholesterol')
# Monomer('levonorgestrel')
# Monomer('ruxolitinib')
# Monomer('mebendazole')
# Monomer('medroxyprogesterone_acetate')
# Monomer('methamphetamine')
# Monomer('diethyl_maleate')
# Monomer('tofacitinib')
# Monomer('promegestone')
# Monomer('potassium_chromate')
# Monomer('copper_II__oxide')
# Monomer('nitroprusside')
# Monomer('norethisterone')
# Monomer('_25R__cholest_5_ene_3beta_26_diol')
# Monomer('fenbendazole')
# Monomer('bleomycin_A5')
# Monomer('dorsomorphin')
# Monomer('GW_3965')
# Monomer('p2_4_dibromophenyl_2_4_5_tribromophenyl_ether')
# Monomer('pioglitazone')
# Monomer('carbon_black')
# Monomer('pentanal')
# Monomer('chromium_trinitrate')
# Monomer('sodium_dodecyl_sulfate')
# Monomer('SB_431542')
# Monomer('troglitazone')
# Monomer('Verbenalin')
# Monomer('CXCL12')
# Monomer('HSP90B1')
# Monomer('STAT3', ['Y705'], {'Y705': ['u', 'p']})
# Monomer('TGFB1')
# Monomer('TNF')
# Monomer('CAT')
# Monomer('CGB5')
# Monomer('CGB8')
# Monomer('CREB3L1')
# Monomer('CGB3')
# Monomer('SULF1')
# Monomer('CYP4Z1')
# Monomer('CSF1')
# Monomer('CTNNB1')
# Monomer('CXCR4')
# Monomer('EGF')
# Monomer('FOXA2')
# Monomer('IFNA1')
# Monomer('IFNA13')
# Monomer('IGF1')
# Monomer('IL18')
# Monomer('IL1A')
# Monomer('IL1B')
# Monomer('APOA1')
# Monomer('nitric_oxide')
# Monomer('cyclic_AMP')
# Monomer('JUN')
# Monomer('MT1L')
# Monomer('NOG')
# Monomer('ATF4')
# Monomer('PPARG')
# Monomer('PTGS2')
# Monomer('GSK_J4')
# Monomer('p4_methyl_7_diethylaminocoumarin')
# Monomer('urushiol')
# Monomer('cobaltiprotoporphyrin')
# Monomer('exochelins')
# Monomer('p3_dimethylaminopropylamine')
# Monomer('tris_1_3_dichloro_2_propyl_phosphate')
# Monomer('gallium_nitrate')
# Monomer('zomepirac_glucuronide')
# Monomer('cadmium_acetate')
# Monomer('lanthanum_chloride')
# Monomer('titanium_alloy__TiAl6V4_')
# Monomer('iron_II__ascorbic_acid_complex')
# Monomer('tolmetin_glucuronide')
# Monomer('polyhexamethyleneguanidine')
# Monomer('quinone_methide')
# Monomer('p1_2_diethyl_3_hydroxypyridin_4_one')
# Monomer('copper_histidine')
# Monomer('macrophage_stimulatory_lipopeptide_2')
# Monomer('p7_8_diacetoxy_4_methylcoumarin')
# Monomer('pluronic_block_copolymer_p85')
# Monomer('TO_901317')
# Monomer('p2__4_amino_3_methylphenyl__5_fluorobenzothiazole')
# Monomer('lipopolysaccharide__Helicobacter_pylori')
# Monomer('beta_hydroxy_simvastatin_acid')
# Monomer('delta_4__tibolone')
# Monomer('cobalt_nickel_chromium_molybdenum_alloy')
# Monomer('ICG_001')
# Monomer('fluor_edenite')
# Monomer('_4_amino_1_4_dihydro_3__2_pyridyl__5_thioxo_1_2_4_triazole_copper_II_')
# Monomer('p4__3__2_propyl_3_hydroxy_4_acetyl_phenoxy_propyloxyphenoxy_acetic_acid')
# Monomer('benzyl_cinnamate')
# Monomer('xiongshao')
# Monomer('Fedratinib')
# Monomer('p2_hydroxymethyl_2_methoxymethylazabicyclo_2_2_2_octan_3_one')
# Monomer('bis_N_N_dimethylamino_2__N_methylpyrrolyl_methyl_cyclopentadienyl_titanium__IV_')
# Monomer('p7__benzylamino__1_3_4_8_tetrahydropyrrolo_4_3_2_de_quinolin_8_1H__one')
# Monomer('PCI_5002')
# Monomer('NSC668394')
# Monomer('bis_cysteinato_zincate_lI_')
# Monomer('Drugs__Chinese_Herbal')
# Monomer('Ferric_Compounds')
# Monomer('Humic_Substances')
# Monomer('Plant_Oils')
# Monomer('Smoke')
# Monomer('Progesterone_Congeners')
# Monomer('copper_atom')
# Monomer('zinc_0_')
# Monomer('LDL_oxidation', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('mitotic_S_phase', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('cell_population_proliferation', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('endothelial_cell_activation', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('Atherosclerosis', ['activity'], {'activity': ['inactive', 'active']})
# Monomer('CSNK2A1')
# Monomer('p11_dehydro_thromboxane_B2')
# Monomer('high_density_lipoprotein_cholesterol')
# Monomer('ANGPTL4')
# Monomer('CETP')
# Monomer('ABCA1')
# Monomer('APOA4')
# Monomer('APOC3')
# Monomer('vitamin_K')
# Monomer('LEPR')
# Monomer('LIPC')
# Monomer('LPL')
# Monomer('MMP9')
# Monomer('PLTP')
# Monomer('PON1')
# Rule('LSR_activates_AD_activity', LSR() + AD(activity='inactive') >> LSR() + AD(activity='active'), kf_la_act_1)
# Rule('APOE_activates_tumor_cell_invasion_activity', APOE() + tumor_cell_invasion(activity='inactive') >> APOE() + tumor_cell_invasion(activity='active'), kf_at_act_1)
# Rule('APOE_activates_endocytosis_activity', APOE() + endocytosis(activity='inactive') >> APOE() + endocytosis(activity='active'), kf_ae_act_1)
# Rule('APOE_activates_cell_cycle_activity', APOE() + cell_cycle(activity='inactive') >> APOE() + cell_cycle(activity='active'), kf_ac_act_1)
# Rule('LSR_APOE_bind', LSR(apolipoprotein=None) + APOE(lsr=None) >> LSR(apolipoprotein=1) % APOE(lsr=1), kf_la_bind_1)
# Rule('LSR_APOE_dissociate', LSR(apolipoprotein=1) % APOE(lsr=1) >> LSR(apolipoprotein=None) + APOE(lsr=None), kr_la_bind_1)
# Rule('APOE_LRP1_bind', APOE(lrp1=None) + LRP1(apolipoprotein=None) >> APOE(lrp1=1) % LRP1(apolipoprotein=1), kf_al_bind_1)
# Rule('APOE_LRP1_dissociate', APOE(lrp1=1) % LRP1(apolipoprotein=1) >> APOE(lrp1=None) + LRP1(apolipoprotein=None), kr_al_bind_1)
# Rule('Oxidized_High_Density_Lipoprotein_degrades_APOE', Oxidized_High_Density_Lipoprotein() + APOE() >> Oxidized_High_Density_Lipoprotein() + None, kf_oa_deg_1)
# Rule('hsa_miR_1908_5p_degrades_APOE', hsa_miR_1908_5p() + APOE() >> hsa_miR_1908_5p() + None, kf_ha_deg_1)
# Rule('hsa_miR_199a_3p_degrades_APOE', hsa_miR_199a_3p() + APOE() >> hsa_miR_199a_3p() + None, kf_ha_deg_2)
# Rule('hsa_miR_199a_5p_degrades_APOE', hsa_miR_199a_5p() + APOE() >> hsa_miR_199a_5p() + None, kf_ha_deg_3)
# Rule('zearalenone_degrades_APOE', zearalenone() + APOE() >> zearalenone() + None, kf_za_deg_1)
# Rule('disodium_selenite_pentahydrate_degrades_VEGFA', disodium_selenite_pentahydrate() + VEGFA() >> disodium_selenite_pentahydrate() + None, kf_dv_deg_1)
# Rule('disodium_selenite_pentahydrate_degrades_PON2', disodium_selenite_pentahydrate() + PON2() >> disodium_selenite_pentahydrate() + None, kf_dp_deg_1)
# Rule('tyrphostin_B42_degrades_VEGFA', tyrphostin_B42() + VEGFA() >> tyrphostin_B42() + None, kf_tv_deg_1)
# Rule('meclocycline_degrades_VEGFA', meclocycline() + VEGFA() >> meclocycline() + None, kf_mv_deg_1)
# Rule('lanatoside_C_degrades_VEGFA', lanatoside_C() + VEGFA() >> lanatoside_C() + None, kf_lv_deg_1)
# Rule('ethylisopropylamiloride_degrades_VEGFA', ethylisopropylamiloride() + VEGFA() >> ethylisopropylamiloride() + None, kf_ev_deg_1)
# Rule('JQ1_degrades_VEGFA', JQ1() + VEGFA() >> JQ1() + None, kf_jv_deg_1)
# Rule('JQ1_degrades_PON2', JQ1() + PON2() >> JQ1() + None, kf_jp_deg_1)
# Rule('all_trans_retinoic_acid_degrades_VEGFA', all_trans_retinoic_acid() + VEGFA() >> all_trans_retinoic_acid() + None, kf_av_deg_1)
# Rule('all_trans_retinoic_acid_degrades_CHRM2', all_trans_retinoic_acid() + CHRM2() >> all_trans_retinoic_acid() + None, kf_ac_deg_1)
# Rule('all_trans_retinoic_acid_degrades_APOE', all_trans_retinoic_acid() + APOE() >> all_trans_retinoic_acid() + None, kf_aa_deg_1)
# Rule('all_trans_retinoic_acid_degrades_PON2', all_trans_retinoic_acid() + PON2() >> all_trans_retinoic_acid() + None, kf_ap_deg_1)
# Rule('hexadecanoic_acid_degrades_MT2A', hexadecanoic_acid() + MT2A() >> hexadecanoic_acid() + None, kf_hm_deg_1)
# Rule('juglone_degrades_VEGFA', juglone() + VEGFA() >> juglone() + None, kf_jv_deg_2)
# Rule('luteolin_degrades_VEGFA', luteolin() + VEGFA() >> luteolin() + None, kf_lv_deg_2)
# Rule('palmatine_degrades_VEGFA', palmatine() + VEGFA() >> palmatine() + None, kf_pv_deg_1)
# Rule('DDT_degrades_MT2A', DDT() + MT2A() >> DDT() + None, kf_dm_deg_1)
# Rule('oleic_acid_degrades_APOE', oleic_acid() + APOE() >> oleic_acid() + None, kf_oa_deg_2)
# Rule('hydrogen_peroxide_degrades_MT2A', hydrogen_peroxide() + MT2A() >> hydrogen_peroxide() + None, kf_hm_deg_2)
# Rule('hydrogen_peroxide_degrades_PON2', hydrogen_peroxide() + PON2() >> hydrogen_peroxide() + None, kf_hp_deg_1)
# Rule('p17beta_hydroxy_5alpha_androstan_3_one_degrades_MT2A', p17beta_hydroxy_5alpha_androstan_3_one() + MT2A() >> p17beta_hydroxy_5alpha_androstan_3_one() + None, kf_1m_deg_1)
# Rule('triclosan_degrades_VEGFA', triclosan() + VEGFA() >> triclosan() + None, kf_tv_deg_2)
# Rule('bilirubin_IXalpha_degrades_PON2', bilirubin_IXalpha() + PON2() >> bilirubin_IXalpha() + None, kf_bp_deg_1)
# Rule('p2_methylcholine_degrades_MT2A', p2_methylcholine() + MT2A() >> p2_methylcholine() + None, kf_2m_deg_1)
# Rule('glucose_degrades_VEGFA', glucose() + VEGFA() >> glucose() + None, kf_gv_deg_1)
# Rule('cortisol_degrades_VEGFA', cortisol() + VEGFA() >> cortisol() + None, kf_cv_deg_1)
# Rule('calcitriol_degrades_VEGFA', calcitriol() + VEGFA() >> calcitriol() + None, kf_cv_deg_2)
# Rule('puromycin_degrades_VEGFA', puromycin() + VEGFA() >> puromycin() + None, kf_pv_deg_2)
# Rule('apigenin_degrades_VEGFA', apigenin() + VEGFA() >> apigenin() + None, kf_av_deg_2)
# Rule('_2_4_dichlorophenoxy_acetate_degrades_VEGFA', _2_4_dichlorophenoxy_acetate() + VEGFA() >> _2_4_dichlorophenoxy_acetate() + None, kf__v_deg_1)
# Rule('acetylcysteine_degrades_VEGFA', acetylcysteine() + VEGFA() >> acetylcysteine() + None, kf_av_deg_3)
# Rule('Antimycin_A_degrades_VEGFA', Antimycin_A() + VEGFA() >> Antimycin_A() + None, kf_av_deg_4)
# Rule('ascorbic_acid_degrades_VEGFA', ascorbic_acid() + VEGFA() >> ascorbic_acid() + None, kf_av_deg_5)
# Rule('copper_II__sulfate_degrades_PON2', copper_II__sulfate() + PON2() >> copper_II__sulfate() + None, kf_cp_deg_1)
# Rule('estradiol_degrades_MT2A', estradiol() + MT2A() >> estradiol() + None, kf_em_deg_1)
# Rule('lead_atom_degrades_ACHE', lead_atom() + ACHE() >> lead_atom() + None, kf_la_deg_1)
# Rule('lead_atom_degrades_VEGFA', lead_atom() + VEGFA() >> lead_atom() + None, kf_lv_deg_3)
# Rule('lead_atom_degrades_APOE', lead_atom() + APOE() >> lead_atom() + None, kf_la_deg_2)
# Rule('aflatoxin_B1_degrades_APOE', aflatoxin_B1() + APOE() >> aflatoxin_B1() + None, kf_aa_deg_2)
# Rule('methyl_methanesulfonate_degrades_PON2', methyl_methanesulfonate() + PON2() >> methyl_methanesulfonate() + None, kf_mp_deg_1)
# Rule('polyphenol_degrades_APOE', polyphenol() + APOE() >> polyphenol() + None, kf_pa_deg_1)
# Rule('zinc_atom_degrades_VEGFA', zinc_atom() + VEGFA() >> zinc_atom() + None, kf_zv_deg_1)
# Rule('folic_acid_degrades_VEGFA', folic_acid() + VEGFA() >> folic_acid() + None, kf_fv_deg_1)
# Rule('arsenic_atom_degrades_MT2A', arsenic_atom() + MT2A() >> arsenic_atom() + None, kf_am_deg_1)
# Rule('selenium_atom_degrades_PON2', selenium_atom() + PON2() >> selenium_atom() + None, kf_sp_deg_1)
# Rule('cobalt_atom_degrades_APOE', cobalt_atom() + APOE() >> cobalt_atom() + None, kf_ca_deg_1)
# Rule('camptothecin_degrades_VEGFA', camptothecin() + VEGFA() >> camptothecin() + None, kf_cv_deg_3)
# Rule('oxytetracycline_degrades_VEGFA', oxytetracycline() + VEGFA() >> oxytetracycline() + None, kf_ov_deg_1)
# Rule('paraoxon_degrades_ACHE', paraoxon() + ACHE() >> paraoxon() + None, kf_pa_deg_2)
# Rule('paraoxon_degrades_CHRM2', paraoxon() + CHRM2() >> paraoxon() + None, kf_pc_deg_1)
# Rule('chloroacetaldehyde_degrades_MT2A', chloroacetaldehyde() + MT2A() >> chloroacetaldehyde() + None, kf_cm_deg_1)
# Rule('resveratrol_degrades_VEGFA', resveratrol() + VEGFA() >> resveratrol() + None, kf_rv_deg_1)
# Rule('cisplatin_degrades_VEGFA', cisplatin() + VEGFA() >> cisplatin() + None, kf_cv_deg_4)
# Rule('cisplatin_degrades_APOE', cisplatin() + APOE() >> cisplatin() + None, kf_ca_deg_2)
# Rule('cisplatin_degrades_MT2A', cisplatin() + MT2A() >> cisplatin() + None, kf_cm_deg_2)
# Rule('parathion_degrades_ACHE', parathion() + ACHE() >> parathion() + None, kf_pa_deg_3)
# Rule('parathion_degrades_MT2A', parathion() + MT2A() >> parathion() + None, kf_pm_deg_1)
# Rule('genistein_degrades_VEGFA', genistein() + VEGFA() >> genistein() + None, kf_gv_deg_2)
# Rule('nickel_atom_degrades_APOE', nickel_atom() + APOE() >> nickel_atom() + None, kf_na_deg_1)
# Rule('p2_3_7_8_tetrachlorodibenzodioxine_degrades_ACHE', p2_3_7_8_tetrachlorodibenzodioxine() + ACHE() >> p2_3_7_8_tetrachlorodibenzodioxine() + None, kf_2a_deg_1)
# Rule('p2_3_7_8_tetrachlorodibenzodioxine_degrades_MT2A', p2_3_7_8_tetrachlorodibenzodioxine() + MT2A() >> p2_3_7_8_tetrachlorodibenzodioxine() + None, kf_2m_deg_2)
# Rule('methylmercury_chloride_degrades_VEGFA', methylmercury_chloride() + VEGFA() >> methylmercury_chloride() + None, kf_mv_deg_2)
# Rule('methylmercury_chloride_degrades_APOE', methylmercury_chloride() + APOE() >> methylmercury_chloride() + None, kf_ma_deg_1)
# Rule('rutin_degrades_VEGFA', rutin() + VEGFA() >> rutin() + None, kf_rv_deg_2)
# Rule('cytarabine_degrades_MT2A', cytarabine() + MT2A() >> cytarabine() + None, kf_cm_deg_3)
# Rule('doxorubicin_degrades_VEGFA', doxorubicin() + VEGFA() >> doxorubicin() + None, kf_dv_deg_2)
# Rule('doxorubicin_degrades_CHRM2', doxorubicin() + CHRM2() >> doxorubicin() + None, kf_dc_deg_1)
# Rule('doxorubicin_degrades_MT2A', doxorubicin() + MT2A() >> doxorubicin() + None, kf_dm_deg_2)
# Rule('doxorubicin_degrades_PON2', doxorubicin() + PON2() >> doxorubicin() + None, kf_dp_deg_2)
# Rule('flavanones_degrades_VEGFA', flavanones() + VEGFA() >> flavanones() + None, kf_fv_deg_2)
# Rule('p2_methoxy_17beta_estradiol_degrades_VEGFA', p2_methoxy_17beta_estradiol() + VEGFA() >> p2_methoxy_17beta_estradiol() + None, kf_2v_deg_1)
# Rule('sodium_arsenite_degrades_VEGFA', sodium_arsenite() + VEGFA() >> sodium_arsenite() + None, kf_sv_deg_1)
# Rule('sodium_arsenite_degrades_APOE', sodium_arsenite() + APOE() >> sodium_arsenite() + None, kf_sa_deg_1)
# Rule('tunicamycin_degrades_PON2', tunicamycin() + PON2() >> tunicamycin() + None, kf_tp_deg_1)
# Rule('baicalein_degrades_VEGFA', baicalein() + VEGFA() >> baicalein() + None, kf_bv_deg_1)
# Rule('benzo_a_pyrene_degrades_ACHE', benzo_a_pyrene() + ACHE() >> benzo_a_pyrene() + None, kf_ba_deg_1)
# Rule('benzo_a_pyrene_degrades_VEGFA', benzo_a_pyrene() + VEGFA() >> benzo_a_pyrene() + None, kf_bv_deg_2)
# Rule('benzo_a_pyrene_degrades_MT2A', benzo_a_pyrene() + MT2A() >> benzo_a_pyrene() + None, kf_bm_deg_1)
# Rule('beclomethasone_degrades_VEGFA', beclomethasone() + VEGFA() >> beclomethasone() + None, kf_bv_deg_3)
# Rule('silicon_dioxide_degrades_VEGFA', silicon_dioxide() + VEGFA() >> silicon_dioxide() + None, kf_sv_deg_2)
# Rule('gallic_acid_degrades_VEGFA', gallic_acid() + VEGFA() >> gallic_acid() + None, kf_gv_deg_3)
# Rule('betamethasone_degrades_VEGFA', betamethasone() + VEGFA() >> betamethasone() + None, kf_bv_deg_4)
# Rule('alclometasone_dipropionate_degrades_VEGFA', alclometasone_dipropionate() + VEGFA() >> alclometasone_dipropionate() + None, kf_av_deg_6)
# Rule('benzethonium_chloride_degrades_VEGFA', benzethonium_chloride() + VEGFA() >> benzethonium_chloride() + None, kf_bv_deg_5)
# Rule('oxaliplatin_degrades_MT2A', oxaliplatin() + MT2A() >> oxaliplatin() + None, kf_om_deg_1)
# Rule('Proscillaridin_degrades_VEGFA', Proscillaridin() + VEGFA() >> Proscillaridin() + None, kf_pv_deg_3)
# Rule('budesonide_degrades_VEGFA', budesonide() + VEGFA() >> budesonide() + None, kf_bv_deg_6)
# Rule('butein_degrades_VEGFA', butein() + VEGFA() >> butein() + None, kf_bv_deg_7)
# Rule('chromium_6___degrades_VEGFA', chromium_6__() + VEGFA() >> chromium_6__() + None, kf_cv_deg_5)
# Rule('bisphenol_A_degrades_VEGFA', bisphenol_A() + VEGFA() >> bisphenol_A() + None, kf_bv_deg_8)
# Rule('bisphenol_A_degrades_MT2A', bisphenol_A() + MT2A() >> bisphenol_A() + None, kf_bm_deg_2)
# Rule('vitamin_E_degrades_VEGFA', vitamin_E() + VEGFA() >> vitamin_E() + None, kf_vv_deg_1)
# Rule('vitamin_E_degrades_PON2', vitamin_E() + PON2() >> vitamin_E() + None, kf_vp_deg_1)
# Rule('candesartan_degrades_VEGFA', candesartan() + VEGFA() >> candesartan() + None, kf_cv_deg_6)
# Rule('tungsten_molecular_entity_degrades_CHRM2', tungsten_molecular_entity() + CHRM2() >> tungsten_molecular_entity() + None, kf_tc_deg_1)
# Rule('capsaicin_degrades_VEGFA', capsaicin() + VEGFA() >> capsaicin() + None, kf_cv_deg_7)
# Rule('____anisomycin_degrades_VEGFA', ____anisomycin() + VEGFA() >> ____anisomycin() + None, kf__v_deg_2)
# Rule('carbamazepine_degrades_VEGFA', carbamazepine() + VEGFA() >> carbamazepine() + None, kf_cv_deg_8)
# Rule('p2_2__5_5__tetrachlorobiphenyl_degrades_APOE', p2_2__5_5__tetrachlorobiphenyl() + APOE() >> p2_2__5_5__tetrachlorobiphenyl() + None, kf_2a_deg_2)
# Rule('p4_4__sulfonyldiphenol_degrades_VEGFA', p4_4__sulfonyldiphenol() + VEGFA() >> p4_4__sulfonyldiphenol() + None, kf_4v_deg_1)
# Rule('p4_4__sulfonyldiphenol_degrades_MT2A', p4_4__sulfonyldiphenol() + MT2A() >> p4_4__sulfonyldiphenol() + None, kf_4m_deg_1)
# Rule('quinomethionate_degrades_VEGFA', quinomethionate() + VEGFA() >> quinomethionate() + None, kf_qv_deg_1)
# Rule('p3_isobutyl_1_methyl_7H_xanthine_degrades_MT2A', p3_isobutyl_1_methyl_7H_xanthine() + MT2A() >> p3_isobutyl_1_methyl_7H_xanthine() + None, kf_3m_deg_1)
# Rule('tris_2_butoxyethyl__phosphate_degrades_MT2A', tris_2_butoxyethyl__phosphate() + MT2A() >> tris_2_butoxyethyl__phosphate() + None, kf_tm_deg_1)
# Rule('cadmium_dichloride_degrades_VEGFA', cadmium_dichloride() + VEGFA() >> cadmium_dichloride() + None, kf_cv_deg_9)
# Rule('cadmium_dichloride_degrades_MT2A', cadmium_dichloride() + MT2A() >> cadmium_dichloride() + None, kf_cm_deg_4)
# Rule('cerium_trichloride_degrades_APOE', cerium_trichloride() + APOE() >> cerium_trichloride() + None, kf_ca_deg_3)
# Rule('cobalt_dichloride_degrades_VEGFA', cobalt_dichloride() + VEGFA() >> cobalt_dichloride() + None, kf_cv_deg_10)
# Rule('cobalt_dichloride_degrades_PON2', cobalt_dichloride() + PON2() >> cobalt_dichloride() + None, kf_cp_deg_2)
# Rule('Chebulinic_acid_degrades_ACHE', Chebulinic_acid() + ACHE() >> Chebulinic_acid() + None, kf_ca_deg_4)
# Rule('phorbol_13_acetate_12_myristate_degrades_VEGFA', phorbol_13_acetate_12_myristate() + VEGFA() >> phorbol_13_acetate_12_myristate() + None, kf_pv_deg_4)
# Rule('phorbol_13_acetate_12_myristate_degrades_MT2A', phorbol_13_acetate_12_myristate() + MT2A() >> phorbol_13_acetate_12_myristate() + None, kf_pm_deg_2)
# Rule('phosphorus_31_atom_degrades_APOE', phosphorus_31_atom() + APOE() >> phosphorus_31_atom() + None, kf_pa_deg_4)
# Rule('dicrotophos_degrades_PON2', dicrotophos() + PON2() >> dicrotophos() + None, kf_dp_deg_3)
# Rule('coumestrol_degrades_VEGFA', coumestrol() + VEGFA() >> coumestrol() + None, kf_cv_deg_11)
# Rule('chloropicrin_degrades_APOE', chloropicrin() + APOE() >> chloropicrin() + None, kf_ca_deg_5)
# Rule('chloropicrin_degrades_MT2A', chloropicrin() + MT2A() >> chloropicrin() + None, kf_cm_deg_5)
# Rule('atorvastatin_degrades_APOE', atorvastatin() + APOE() >> atorvastatin() + None, kf_aa_deg_3)
# Rule('curcumin_degrades_VEGFA', curcumin() + VEGFA() >> curcumin() + None, kf_cv_deg_12)
# Rule('valproic_acid_degrades_VEGFA', valproic_acid() + VEGFA() >> valproic_acid() + None, kf_vv_deg_2)
# Rule('valproic_acid_degrades_APOE', valproic_acid() + APOE() >> valproic_acid() + None, kf_va_deg_1)
# Rule('valproic_acid_degrades_MT2A', valproic_acid() + MT2A() >> valproic_acid() + None, kf_vm_deg_1)
# Rule('valproic_acid_degrades_PON2', valproic_acid() + PON2() >> valproic_acid() + None, kf_vp_deg_2)
# Rule('cyclophosphamide_degrades_VEGFA', cyclophosphamide() + VEGFA() >> cyclophosphamide() + None, kf_cv_deg_13)
# Rule('cyclosporin_A_degrades_APOE', cyclosporin_A() + APOE() >> cyclosporin_A() + None, kf_ca_deg_6)
# Rule('cyclosporin_A_degrades_PON2', cyclosporin_A() + PON2() >> cyclosporin_A() + None, kf_cp_deg_3)
# Rule('celecoxib_degrades_VEGFA', celecoxib() + VEGFA() >> celecoxib() + None, kf_cv_deg_14)
# Rule('dequalinium_degrades_VEGFA', dequalinium() + VEGFA() >> dequalinium() + None, kf_dv_deg_3)
# Rule('dexamethasone_degrades_VEGFA', dexamethasone() + VEGFA() >> dexamethasone() + None, kf_dv_deg_4)
# Rule('dexamethasone_degrades_MT2A', dexamethasone() + MT2A() >> dexamethasone() + None, kf_dm_deg_3)
# Rule('daunorubicin_degrades_VEGFA', daunorubicin() + VEGFA() >> daunorubicin() + None, kf_dv_deg_5)
# Rule('digoxigenin_degrades_VEGFA', digoxigenin() + VEGFA() >> digoxigenin() + None, kf_dv_deg_6)
# Rule('digitoxigenin_degrades_VEGFA', digitoxigenin() + VEGFA() >> digitoxigenin() + None, kf_dv_deg_7)
# Rule('emodin_degrades_VEGFA', emodin() + VEGFA() >> emodin() + None, kf_ev_deg_2)
# Rule('Deguelin_degrades_VEGFA', Deguelin() + VEGFA() >> Deguelin() + None, kf_dv_deg_8)
# Rule('obeticholic_acid_degrades_APOE', obeticholic_acid() + APOE() >> obeticholic_acid() + None, kf_oa_deg_3)
# Rule('indirubin_3__monoxime_degrades_MT2A', indirubin_3__monoxime() + MT2A() >> indirubin_3__monoxime() + None, kf_im_deg_1)
# Rule('____demecolcine_degrades_VEGFA', ____demecolcine() + VEGFA() >> ____demecolcine() + None, kf__v_deg_3)
# Rule('methotrexate_degrades_VEGFA', methotrexate() + VEGFA() >> methotrexate() + None, kf_mv_deg_3)
# Rule('nimesulide_degrades_VEGFA', nimesulide() + VEGFA() >> nimesulide() + None, kf_nv_deg_1)
# Rule('desogestrel_degrades_APOE', desogestrel() + APOE() >> desogestrel() + None, kf_da_deg_1)
# Rule('digoxin_degrades_VEGFA', digoxin() + VEGFA() >> digoxin() + None, kf_dv_deg_9)
# Rule('vorinostat_degrades_VEGFA', vorinostat() + VEGFA() >> vorinostat() + None, kf_vv_deg_3)
# Rule('vorinostat_degrades_PON2', vorinostat() + PON2() >> vorinostat() + None, kf_vp_deg_3)
# Rule('TAXOTERE_degrades_VEGFA', TAXOTERE() + VEGFA() >> TAXOTERE() + None, kf_tv_deg_3)
# Rule('paracetamol_degrades_VEGFA', paracetamol() + VEGFA() >> paracetamol() + None, kf_pv_deg_5)
# Rule('paracetamol_degrades_APOE', paracetamol() + APOE() >> paracetamol() + None, kf_pa_deg_5)
# Rule('paracetamol_degrades_PON2', paracetamol() + PON2() >> paracetamol() + None, kf_pp_deg_1)
# Rule('p5_fluorouracil_degrades_VEGFA', p5_fluorouracil() + VEGFA() >> p5_fluorouracil() + None, kf_5v_deg_1)
# Rule('dipyridamole_degrades_APOE', dipyridamole() + APOE() >> dipyridamole() + None, kf_da_deg_2)
# Rule('isobutanol_degrades_MT2A', isobutanol() + MT2A() >> isobutanol() + None, kf_im_deg_2)
# Rule('crocidolite_asbestos_degrades_MT2A', crocidolite_asbestos() + MT2A() >> crocidolite_asbestos() + None, kf_cm_deg_6)
# Rule('doxazosin_degrades_VEGFA', doxazosin() + VEGFA() >> doxazosin() + None, kf_dv_deg_10)
# Rule('alvocidib_degrades_VEGFA', alvocidib() + VEGFA() >> alvocidib() + None, kf_av_deg_7)
# Rule('diclofenac_degrades_VEGFA', diclofenac() + VEGFA() >> diclofenac() + None, kf_dv_deg_11)
# Rule('bezafibrate_degrades_APOE', bezafibrate() + APOE() >> bezafibrate() + None, kf_ba_deg_2)
# Rule('embelin_degrades_VEGFA', embelin() + VEGFA() >> embelin() + None, kf_ev_deg_3)
# Rule('emetine_degrades_VEGFA', emetine() + VEGFA() >> emetine() + None, kf_ev_deg_4)
# Rule('methionine_sulfoximine_degrades_VEGFA', methionine_sulfoximine() + VEGFA() >> methionine_sulfoximine() + None, kf_mv_deg_4)
# Rule('enalapril_degrades_APOE', enalapril() + APOE() >> enalapril() + None, kf_ea_deg_1)
# Rule('lithium_chloride_degrades_ACHE', lithium_chloride() + ACHE() >> lithium_chloride() + None, kf_la_deg_3)
# Rule('copper_II__chloride_degrades_MT2A', copper_II__chloride() + MT2A() >> copper_II__chloride() + None, kf_cm_deg_7)
# Rule('indometacin_degrades_VEGFA', indometacin() + VEGFA() >> indometacin() + None, kf_iv_deg_1)
# Rule('indometacin_degrades_MT2A', indometacin() + MT2A() >> indometacin() + None, kf_im_deg_3)
# Rule('arsenous_acid_degrades_VEGFA', arsenous_acid() + VEGFA() >> arsenous_acid() + None, kf_av_deg_8)
# Rule('arsenous_acid_degrades_APOE', arsenous_acid() + APOE() >> arsenous_acid() + None, kf_aa_deg_4)
# Rule('arsenous_acid_degrades_MT2A', arsenous_acid() + MT2A() >> arsenous_acid() + None, kf_am_deg_2)
# Rule('rosiglitazone_degrades_PON2', rosiglitazone() + PON2() >> rosiglitazone() + None, kf_rp_deg_1)
# Rule('p5_aza_2__deoxycytidine_degrades_VEGFA', p5_aza_2__deoxycytidine() + VEGFA() >> p5_aza_2__deoxycytidine() + None, kf_5v_deg_2)
# Rule('p5_aza_2__deoxycytidine_degrades_MT2A', p5_aza_2__deoxycytidine() + MT2A() >> p5_aza_2__deoxycytidine() + None, kf_5m_deg_1)
# Rule('motexafin_gadolinium_degrades_VEGFA', motexafin_gadolinium() + VEGFA() >> motexafin_gadolinium() + None, kf_mv_deg_5)
# Rule('mifepristone_degrades_VEGFA', mifepristone() + VEGFA() >> mifepristone() + None, kf_mv_deg_6)
# Rule('minocycline_degrades_VEGFA', minocycline() + VEGFA() >> minocycline() + None, kf_mv_deg_7)
# Rule('fludrocortisone_degrades_VEGFA', fludrocortisone() + VEGFA() >> fludrocortisone() + None, kf_fv_deg_3)
# Rule('propidium_degrades_VEGFA', propidium() + VEGFA() >> propidium() + None, kf_pv_deg_6)
# Rule('bufalin_degrades_VEGFA', bufalin() + VEGFA() >> bufalin() + None, kf_bv_deg_9)
# Rule('lithium_7_atom_degrades_VEGFA', lithium_7_atom() + VEGFA() >> lithium_7_atom() + None, kf_lv_deg_4)
# Rule('bortezomib_degrades_VEGFA', bortezomib() + VEGFA() >> bortezomib() + None, kf_bv_deg_10)
# Rule('Genipin_degrades_VEGFA', Genipin() + VEGFA() >> Genipin() + None, kf_gv_deg_4)
# Rule('nickel_sulfate_degrades_APOE', nickel_sulfate() + APOE() >> nickel_sulfate() + None, kf_na_deg_2)
# Rule('potassium_dichromate_degrades_MT2A', potassium_dichromate() + MT2A() >> potassium_dichromate() + None, kf_pm_deg_3)
# Rule('cobalt_2___sulfate_degrades_VEGFA', cobalt_2___sulfate() + VEGFA() >> cobalt_2___sulfate() + None, kf_cv_deg_15)
# Rule('alexidine_degrades_VEGFA', alexidine() + VEGFA() >> alexidine() + None, kf_av_deg_9)
# Rule('glucosamine_degrades_VEGFA', glucosamine() + VEGFA() >> glucosamine() + None, kf_gv_deg_5)
# Rule('Honokiol_degrades_VEGFA', Honokiol() + VEGFA() >> Honokiol() + None, kf_hv_deg_1)
# Rule('cetrorelix_degrades_VEGFA', cetrorelix() + VEGFA() >> cetrorelix() + None, kf_cv_deg_16)
# Rule('cetrorelix_degrades_APOE', cetrorelix() + APOE() >> cetrorelix() + None, kf_ca_deg_7)
# Rule('romidepsin_degrades_VEGFA', romidepsin() + VEGFA() >> romidepsin() + None, kf_rv_deg_3)
# Rule('canertinib_degrades_VEGFA', canertinib() + VEGFA() >> canertinib() + None, kf_cv_deg_17)
# Rule('zinc_acetate_degrades_VEGFA', zinc_acetate() + VEGFA() >> zinc_acetate() + None, kf_zv_deg_2)
# Rule('potassium_nitrate_degrades_VEGFA', potassium_nitrate() + VEGFA() >> potassium_nitrate() + None, kf_pv_deg_7)
# Rule('ribavirin_degrades_VEGFA', ribavirin() + VEGFA() >> ribavirin() + None, kf_rv_deg_4)
# Rule('nevirapine_degrades_VEGFA', nevirapine() + VEGFA() >> nevirapine() + None, kf_nv_deg_2)
# Rule('topotecan_degrades_VEGFA', topotecan() + VEGFA() >> topotecan() + None, kf_tv_deg_4)
# Rule('zerumbone_degrades_VEGFA', zerumbone() + VEGFA() >> zerumbone() + None, kf_zv_deg_3)
# Rule('tert_butyl_hydroperoxide_degrades_PON2', tert_butyl_hydroperoxide() + PON2() >> tert_butyl_hydroperoxide() + None, kf_tp_deg_2)
# Rule('p8_bromo_3__5__cyclic_GMP_degrades_VEGFA', p8_bromo_3__5__cyclic_GMP() + VEGFA() >> p8_bromo_3__5__cyclic_GMP() + None, kf_8v_deg_1)
# Rule('N_methyl_4_phenylpyridinium_degrades_APOE', N_methyl_4_phenylpyridinium() + APOE() >> N_methyl_4_phenylpyridinium() + None, kf_na_deg_3)
# Rule('p4_____5_5_8_8_tetramethyl_5_6_7_8_tetrahydronaphthalen_2_yl_carbonyl_amino__benzoic_acid_degrades_PON2', p4_____5_5_8_8_tetramethyl_5_6_7_8_tetrahydronaphthalen_2_yl_carbonyl_amino__benzoic_acid() + PON2() >> p4_____5_5_8_8_tetramethyl_5_6_7_8_tetrahydronaphthalen_2_yl_carbonyl_amino__benzoic_acid() + None, kf_4p_deg_1)
# Rule('ciglitazone_degrades_VEGFA', ciglitazone() + VEGFA() >> ciglitazone() + None, kf_cv_deg_18)
# Rule('LY294002_degrades_VEGFA', LY294002() + VEGFA() >> LY294002() + None, kf_lv_deg_5)
# Rule('andrographolide_degrades_VEGFA', andrographolide() + VEGFA() >> andrographolide() + None, kf_av_deg_10)
# Rule('losartan_degrades_VEGFA', losartan() + VEGFA() >> losartan() + None, kf_lv_deg_6)
# Rule('demethoxycurcumin_degrades_VEGFA', demethoxycurcumin() + VEGFA() >> demethoxycurcumin() + None, kf_dv_deg_12)
# Rule('lycorine_degrades_VEGFA', lycorine() + VEGFA() >> lycorine() + None, kf_lv_deg_7)
# Rule('Delta_9__tetrahydrocannabinol_degrades_VEGFA', Delta_9__tetrahydrocannabinol() + VEGFA() >> Delta_9__tetrahydrocannabinol() + None, kf_dv_deg_13)
# Rule('Delta_9__tetrahydrocannabinol_degrades_MT2A', Delta_9__tetrahydrocannabinol() + MT2A() >> Delta_9__tetrahydrocannabinol() + None, kf_dm_deg_4)
# Rule('melittin_degrades_VEGFA', melittin() + VEGFA() >> melittin() + None, kf_mv_deg_8)
# Rule('metformin_degrades_VEGFA', metformin() + VEGFA() >> metformin() + None, kf_mv_deg_9)
# Rule('metoprolol_degrades_VEGFA', metoprolol() + VEGFA() >> metoprolol() + None, kf_mv_deg_10)
# Rule('withaferin_A_degrades_VEGFA', withaferin_A() + VEGFA() >> withaferin_A() + None, kf_wv_deg_1)
# Rule('GW_7647_degrades_APOE', GW_7647() + APOE() >> GW_7647() + None, kf_ga_deg_1)
# Rule('triamcinolone_acetonide_degrades_VEGFA', triamcinolone_acetonide() + VEGFA() >> triamcinolone_acetonide() + None, kf_tv_deg_5)
# Rule('ICI_118551_degrades_VEGFA', ICI_118551() + VEGFA() >> ICI_118551() + None, kf_iv_deg_2)
# Rule('WIN_55212_2_degrades_VEGFA', WIN_55212_2() + VEGFA() >> WIN_55212_2() + None, kf_wv_deg_2)
# Rule('p5_chloro_7_iodoquinolin_8_ol_degrades_VEGFA', p5_chloro_7_iodoquinolin_8_ol() + VEGFA() >> p5_chloro_7_iodoquinolin_8_ol() + None, kf_5v_deg_3)
# Rule('carbonyl_cyanide_p_trifluoromethoxyphenylhydrazone_degrades_MT2A', carbonyl_cyanide_p_trifluoromethoxyphenylhydrazone() + MT2A() >> carbonyl_cyanide_p_trifluoromethoxyphenylhydrazone() + None, kf_cm_deg_8)
# Rule('niclosamide_degrades_VEGFA', niclosamide() + VEGFA() >> niclosamide() + None, kf_nv_deg_3)
# Rule('sarin_degrades_ACHE', sarin() + ACHE() >> sarin() + None, kf_sa_deg_2)
# Rule('ochratoxin_A_degrades_VEGFA', ochratoxin_A() + VEGFA() >> ochratoxin_A() + None, kf_ov_deg_2)
# Rule('octreotide_degrades_VEGFA', octreotide() + VEGFA() >> octreotide() + None, kf_ov_deg_3)
# Rule('p2__2_amino_3_methoxyphenyl_chromen_4_one_degrades_VEGFA', p2__2_amino_3_methoxyphenyl_chromen_4_one() + VEGFA() >> p2__2_amino_3_methoxyphenyl_chromen_4_one() + None, kf_2v_deg_2)
# Rule('diallyl_trisulfide_degrades_VEGFA', diallyl_trisulfide() + VEGFA() >> diallyl_trisulfide() + None, kf_dv_deg_14)
# Rule('Nonidet_P_40_degrades_VEGFA', Nonidet_P_40() + VEGFA() >> Nonidet_P_40() + None, kf_nv_deg_4)
# Rule('paricalcitol_degrades_APOE', paricalcitol() + APOE() >> paricalcitol() + None, kf_pa_deg_6)
# Rule('Nonylphenol_degrades_VEGFA', Nonylphenol() + VEGFA() >> Nonylphenol() + None, kf_nv_deg_5)
# Rule('Temsirolimus_degrades_VEGFA', Temsirolimus() + VEGFA() >> Temsirolimus() + None, kf_tv_deg_6)
# Rule('GW_4064_degrades_APOE', GW_4064() + APOE() >> GW_4064() + None, kf_ga_deg_2)
# Rule('Salinomycin_degrades_MT2A', Salinomycin() + MT2A() >> Salinomycin() + None, kf_sm_deg_1)
# Rule('phenobarbital_degrades_VEGFA', phenobarbital() + VEGFA() >> phenobarbital() + None, kf_pv_deg_8)
# Rule('phenobarbital_degrades_PON2', phenobarbital() + PON2() >> phenobarbital() + None, kf_pp_deg_2)
# Rule('Enterolactone_degrades_VEGFA', Enterolactone() + VEGFA() >> Enterolactone() + None, kf_ev_deg_5)
# Rule('Tungsten_carbide_degrades_APOE', Tungsten_carbide() + APOE() >> Tungsten_carbide() + None, kf_ta_deg_1)
# Rule('piroxicam_degrades_VEGFA', piroxicam() + VEGFA() >> piroxicam() + None, kf_pv_deg_9)
# Rule('piroxicam_degrades_MT2A', piroxicam() + MT2A() >> piroxicam() + None, kf_pm_deg_4)
# Rule('icariside_II_degrades_VEGFA', icariside_II() + VEGFA() >> icariside_II() + None, kf_iv_deg_3)
# Rule('propranolol_degrades_VEGFA', propranolol() + VEGFA() >> propranolol() + None, kf_pv_deg_10)
# Rule('iron_trichloride_hexahydrate_degrades_MT2A', iron_trichloride_hexahydrate() + MT2A() >> iron_trichloride_hexahydrate() + None, kf_im_deg_4)
# Rule('pyrvinium_degrades_VEGFA', pyrvinium() + VEGFA() >> pyrvinium() + None, kf_pv_deg_11)
# Rule('N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine_degrades_VEGFA', N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine() + VEGFA() >> N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine() + None, kf_nv_deg_6)
# Rule('N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine_degrades_PON2', N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine() + PON2() >> N_N_N__N__tetrakis_2_pyridylmethyl_ethylenediamine() + None, kf_np_deg_1)
# Rule('Rhein_degrades_VEGFA', Rhein() + VEGFA() >> Rhein() + None, kf_rv_deg_5)
# Rule('SB_203580_degrades_VEGFA', SB_203580() + VEGFA() >> SB_203580() + None, kf_sv_deg_3)
# Rule('semaxanib_degrades_VEGFA', semaxanib() + VEGFA() >> semaxanib() + None, kf_sv_deg_4)
# Rule('simvastatin_degrades_VEGFA', simvastatin() + VEGFA() >> simvastatin() + None, kf_sv_deg_5)
# Rule('simvastatin_degrades_APOE', simvastatin() + APOE() >> simvastatin() + None, kf_sa_deg_3)
# Rule('sirolimus_degrades_VEGFA', sirolimus() + VEGFA() >> sirolimus() + None, kf_sv_deg_6)
# Rule('testosterone_enanthate_degrades_APOE', testosterone_enanthate() + APOE() >> testosterone_enanthate() + None, kf_ta_deg_2)
# Rule('dimethyl__phenylmethyl___2__2__4__2_4_4_trimethylpentan_2_yl_phenoxy_ethoxy_ethyl_ammonium_degrades_VEGFA', dimethyl__phenylmethyl___2__2__4__2_4_4_trimethylpentan_2_yl_phenoxy_ethoxy_ethyl_ammonium() + VEGFA() >> dimethyl__phenylmethyl___2__2__4__2_4_4_trimethylpentan_2_yl_phenoxy_ethoxy_ethyl_ammonium() + None, kf_dv_deg_15)
# Rule('thalidomide_degrades_VEGFA', thalidomide() + VEGFA() >> thalidomide() + None, kf_tv_deg_7)
# Rule('thapsigargin_degrades_PON2', thapsigargin() + PON2() >> thapsigargin() + None, kf_tp_deg_3)
# Rule('thimerosal_degrades_VEGFA', thimerosal() + VEGFA() >> thimerosal() + None, kf_tv_deg_8)
# Rule('valsartan_degrades_VEGFA', valsartan() + VEGFA() >> valsartan() + None, kf_vv_deg_4)
# Rule('valsartan_degrades_APOE', valsartan() + APOE() >> valsartan() + None, kf_va_deg_2)
# Rule('SOD2_degrades_VEGFA', SOD2() + VEGFA() >> SOD2() + None, kf_sv_deg_7)
# Rule('SP1_degrades_APOE', SP1() + APOE() >> SP1() + None, kf_sa_deg_4)
# Rule('TEAD1_degrades_APOE', TEAD1() + APOE() >> TEAD1() + None, kf_ta_deg_3)
# Rule('ZNF202_degrades_APOE', ZNF202() + APOE() >> ZNF202() + None, kf_za_deg_2)
# Rule('E2F1_degrades_APOE', E2F1() + APOE() >> E2F1() + None, kf_ea_deg_2)
# Rule('AGT_degrades_APOE', AGT() + APOE() >> AGT() + None, kf_aa_deg_5)
# Rule('GATA3_degrades_APOE', GATA3() + APOE() >> GATA3() + None, kf_ga_deg_3)
# Rule('HIF1A_degrades_VEGFA', HIF1A() + VEGFA() >> HIF1A() + None, kf_hv_deg_2)
# Rule('HOXA4_degrades_APOE', HOXA4() + APOE() >> HOXA4() + None, kf_ha_deg_4)
# Rule('IFNG_degrades_APOE', IFNG() + APOE() >> IFNG() + None, kf_ia_deg_1)
# Rule('IL6_degrades_APOE', IL6() + APOE() >> IL6() + None, kf_ia_deg_2)
# Rule('INS_degrades_MT2A', INS() + MT2A() >> INS() + None, kf_im_deg_5)
# Rule('APOE_degrades_Oxidized_Low_Density_Lipoprotein', APOE() + Oxidized_Low_Density_Lipoprotein() >> APOE() + None, kf_ao_deg_1)
# Rule('APOE_degrades_reactive_oxygen_species', APOE() + reactive_oxygen_species() >> APOE() + None, kf_ar_deg_1)
# ...
# Annotation(_4_amino_1_4_dihydro_3__2_pyridyl__5_thioxo_1_2_4_triazole_copper_II__produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(_4_amino_1_4_dihydro_3__2_pyridyl__5_thioxo_1_2_4_triazole_copper_II__produces_MT2A, '_4_amino_1_4_dihydro_3__2_pyridyl__5_thioxo_1_2_4_triazole_copper_II_', 'rule_has_subject')
# Annotation(p4__3__2_propyl_3_hydroxy_4_acetyl_phenoxy_propyloxyphenoxy_acetic_acid_produces_VEGFA, '90a9c4f6-3484-4039-9f75-7215d36e813a', 'from_indra_statement')
# Annotation(p4__3__2_propyl_3_hydroxy_4_acetyl_phenoxy_propyloxyphenoxy_acetic_acid_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(p4__3__2_propyl_3_hydroxy_4_acetyl_phenoxy_propyloxyphenoxy_acetic_acid_produces_VEGFA, 'p4__3__2_propyl_3_hydroxy_4_acetyl_phenoxy_propyloxyphenoxy_acetic_acid', 'rule_has_subject')
# Annotation(benzyl_cinnamate_produces_MT2A, '6f974524-5d50-40ea-8b5f-d485d5a2f6da', 'from_indra_statement')
# Annotation(benzyl_cinnamate_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(benzyl_cinnamate_produces_MT2A, 'benzyl_cinnamate', 'rule_has_subject')
# Annotation(xiongshao_produces_VEGFA, '2e39724b-6233-4185-9196-2423b081f1f0', 'from_indra_statement')
# Annotation(xiongshao_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(xiongshao_produces_VEGFA, 'xiongshao', 'rule_has_subject')
# Annotation(Fedratinib_produces_VEGFA, '3af4226d-5df5-4791-9e6d-c6390759ac09', 'from_indra_statement')
# Annotation(Fedratinib_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Fedratinib_produces_VEGFA, 'Fedratinib', 'rule_has_subject')
# Annotation(p2_hydroxymethyl_2_methoxymethylazabicyclo_2_2_2_octan_3_one_produces_VEGFA, '2fb59857-1706-4806-a435-f6943ad4b434', 'from_indra_statement')
# Annotation(p2_hydroxymethyl_2_methoxymethylazabicyclo_2_2_2_octan_3_one_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(p2_hydroxymethyl_2_methoxymethylazabicyclo_2_2_2_octan_3_one_produces_VEGFA, 'p2_hydroxymethyl_2_methoxymethylazabicyclo_2_2_2_octan_3_one', 'rule_has_subject')
# Annotation(jinfukang_produces_ACHE, '80c34006-d233-4ddc-976a-bf4ad59ba525', 'from_indra_statement')
# Annotation(jinfukang_produces_ACHE, 'ACHE', 'rule_has_object')
# Annotation(jinfukang_produces_ACHE, 'jinfukang', 'rule_has_subject')
# Annotation(jinfukang_produces_VEGFA, '8c887e2d-d46e-47de-b4bf-ae83cffa1c36', 'from_indra_statement')
# Annotation(jinfukang_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(jinfukang_produces_VEGFA, 'jinfukang', 'rule_has_subject')
# Annotation(bis_N_N_dimethylamino_2__N_methylpyrrolyl_methyl_cyclopentadienyl_titanium__IV__produces_MT2A, 'b2ba04f7-4606-4777-9b3c-f66fb7db8f7b', 'from_indra_statement')
# Annotation(bis_N_N_dimethylamino_2__N_methylpyrrolyl_methyl_cyclopentadienyl_titanium__IV__produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(bis_N_N_dimethylamino_2__N_methylpyrrolyl_methyl_cyclopentadienyl_titanium__IV__produces_MT2A, 'bis_N_N_dimethylamino_2__N_methylpyrrolyl_methyl_cyclopentadienyl_titanium__IV_', 'rule_has_subject')
# Annotation(p7__benzylamino__1_3_4_8_tetrahydropyrrolo_4_3_2_de_quinolin_8_1H__one_produces_VEGFA, 'a53a15a5-a99b-40c2-8545-2da8da9331d7', 'from_indra_statement')
# Annotation(p7__benzylamino__1_3_4_8_tetrahydropyrrolo_4_3_2_de_quinolin_8_1H__one_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(p7__benzylamino__1_3_4_8_tetrahydropyrrolo_4_3_2_de_quinolin_8_1H__one_produces_VEGFA, 'p7__benzylamino__1_3_4_8_tetrahydropyrrolo_4_3_2_de_quinolin_8_1H__one', 'rule_has_subject')
# Annotation(PCI_5002_produces_VEGFA, 'adfa23ae-feaa-49be-90c8-e1157b44444f', 'from_indra_statement')
# Annotation(PCI_5002_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(PCI_5002_produces_VEGFA, 'PCI_5002', 'rule_has_subject')
# Annotation(PCI_5002_produces_MT2A, '63f8ae1a-17ae-43c1-9334-a960cb2b860b', 'from_indra_statement')
# Annotation(PCI_5002_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(PCI_5002_produces_MT2A, 'PCI_5002', 'rule_has_subject')
# Annotation(NSC668394_produces_VEGFA, '7f8dc06d-0cdc-452e-8532-83e50175e1c3', 'from_indra_statement')
# Annotation(NSC668394_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(NSC668394_produces_VEGFA, 'NSC668394', 'rule_has_subject')
# Annotation(bis_cysteinato_zincate_lI__produces_MT2A, '4efe5ae5-7bfd-419c-ab31-ff5d5e815cd7', 'from_indra_statement')
# Annotation(bis_cysteinato_zincate_lI__produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(bis_cysteinato_zincate_lI__produces_MT2A, 'bis_cysteinato_zincate_lI_', 'rule_has_subject')
# Annotation(Aerosols_produces_VEGFA, '1b3a8b75-ea44-4172-b499-eca5dec4c664', 'from_indra_statement')
# Annotation(Aerosols_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Aerosols_produces_VEGFA, 'Aerosols', 'rule_has_subject')
# Annotation(Aerosols_produces_MT2A, '4a9de60c-c206-4ca3-a52a-fdbb5ce083c1', 'from_indra_statement')
# Annotation(Aerosols_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(Aerosols_produces_MT2A, 'Aerosols', 'rule_has_subject')
# Annotation(Air_Pollutants__Occupational_produces_VEGFA, '8ccdbd45-d98c-4399-8338-45d8fd78394c', 'from_indra_statement')
# Annotation(Air_Pollutants__Occupational_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Air_Pollutants__Occupational_produces_VEGFA, 'Air_Pollutants__Occupational', 'rule_has_subject')
# Annotation(Vehicle_Emissions_produces_VEGFA, '232a3f26-8e7a-476e-b4ed-655aa6a7e52f', 'from_indra_statement')
# Annotation(Vehicle_Emissions_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Vehicle_Emissions_produces_VEGFA, 'Vehicle_Emissions', 'rule_has_subject')
# Annotation(Vehicle_Emissions_produces_MT2A, '0f4fa5b2-1528-4d26-8125-147aa2a9c884', 'from_indra_statement')
# Annotation(Vehicle_Emissions_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(Vehicle_Emissions_produces_MT2A, 'Vehicle_Emissions', 'rule_has_subject')
# Annotation(Drugs__Chinese_Herbal_produces_VEGFA, '0255711d-aebe-4e88-9ef7-96a0d82ba1bb', 'from_indra_statement')
# Annotation(Drugs__Chinese_Herbal_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Drugs__Chinese_Herbal_produces_VEGFA, 'Drugs__Chinese_Herbal', 'rule_has_subject')
# Annotation(Ferric_Compounds_produces_MT2A, '35b3dd03-0fc1-49d3-983a-7071dbbdbda8', 'from_indra_statement')
# Annotation(Ferric_Compounds_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(Ferric_Compounds_produces_MT2A, 'Ferric_Compounds', 'rule_has_subject')
# Annotation(Humic_Substances_produces_VEGFA, 'fdcb4a5a-3fc3-4f40-9317-5d1a346867b2', 'from_indra_statement')
# Annotation(Humic_Substances_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Humic_Substances_produces_VEGFA, 'Humic_Substances', 'rule_has_subject')
# Annotation(Plant_Extracts_produces_APOE, '725f9361-d79b-4fbe-a5b6-dade3ed2dc41', 'from_indra_statement')
# Annotation(Plant_Extracts_produces_APOE, 'APOE', 'rule_has_object')
# Annotation(Plant_Extracts_produces_APOE, 'Plant_Extracts', 'rule_has_subject')
# Annotation(Plant_Extracts_produces_PON2, '143e3e1b-9bd1-4d6a-ba55-65da095cbe40', 'from_indra_statement')
# Annotation(Plant_Extracts_produces_PON2, 'PON2', 'rule_has_object')
# Annotation(Plant_Extracts_produces_PON2, 'Plant_Extracts', 'rule_has_subject')
# Annotation(Plant_Oils_produces_VEGFA, '11d56994-bc87-4946-9cb6-0a523fd23594', 'from_indra_statement')
# Annotation(Plant_Oils_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Plant_Oils_produces_VEGFA, 'Plant_Oils', 'rule_has_subject')
# Annotation(Smoke_produces_ACHE, '28595de0-008c-425e-951e-0a4c3a2dd09b', 'from_indra_statement')
# Annotation(Smoke_produces_ACHE, 'ACHE', 'rule_has_object')
# Annotation(Smoke_produces_ACHE, 'Smoke', 'rule_has_subject')
# Annotation(Tobacco_Smoke_Pollution_produces_VEGFA, 'a78ee225-0a55-4611-9caa-e991043bbb35', 'from_indra_statement')
# Annotation(Tobacco_Smoke_Pollution_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Tobacco_Smoke_Pollution_produces_VEGFA, 'Tobacco_Smoke_Pollution', 'rule_has_subject')
# Annotation(Tobacco_Smoke_Pollution_produces_APOE, '4b1f470d-d7d6-4ae7-b6a9-31354a55cc82', 'from_indra_statement')
# Annotation(Tobacco_Smoke_Pollution_produces_APOE, 'APOE', 'rule_has_object')
# Annotation(Tobacco_Smoke_Pollution_produces_APOE, 'Tobacco_Smoke_Pollution', 'rule_has_subject')
# Annotation(Tobacco_Smoke_Pollution_produces_MT2A, 'bf50f4bc-ed69-486f-9bec-6fe174f9901a', 'from_indra_statement')
# Annotation(Tobacco_Smoke_Pollution_produces_MT2A, 'MT2A', 'rule_has_object')
# Annotation(Tobacco_Smoke_Pollution_produces_MT2A, 'Tobacco_Smoke_Pollution', 'rule_has_subject')
# Annotation(Progesterone_Congeners_produces_VEGFA, '1574a45e-b2e7-4dc1-a99b-d7045b4cf393', 'from_indra_statement')
# Annotation(Progesterone_Congeners_produces_VEGFA, 'VEGFA', 'rule_has_object')
# Annotation(Progesterone_Congeners_produces_VEGFA, 'Progesterone_Congeners', 'rule_has_subject')
# Annotation(copper_atom_deactivates_APOE_activity, 'copper_atom', 'rule_has_subject')
# Annotation(copper_atom_deactivates_APOE_activity, 'APOE', 'rule_has_object')
# Annotation(copper_atom_deactivates_APOE_activity, '29dd69b1-ee07-41c7-b3af-2b5d7e3a531a', 'from_indra_statement')
# Annotation(zinc_0__deactivates_APOE_activity, 'zinc_0_', 'rule_has_subject')
# Annotation(zinc_0__deactivates_APOE_activity, 'APOE', 'rule_has_object')
# Annotation(zinc_0__deactivates_APOE_activity, 'c21d32e0-0a1d-4e4b-a7b2-3bf834b72147', 'from_indra_statement')
# Annotation(zinc_dichloride_deactivates_APOE_activity, 'zinc_dichloride', 'rule_has_subject')
# Annotation(zinc_dichloride_deactivates_APOE_activity, 'APOE', 'rule_has_object')
# Annotation(zinc_dichloride_deactivates_APOE_activity, '6ef86779-b8be-4f8a-a1ab-8bd33edf4dc6', 'from_indra_statement')
# Annotation(zinc_acetate_deactivates_APOE_activity, 'zinc_acetate', 'rule_has_subject')
# Annotation(zinc_acetate_deactivates_APOE_activity, 'APOE', 'rule_has_object')
# Annotation(zinc_acetate_deactivates_APOE_activity, 'd5d215e7-6242-4b0f-8e73-1e8aaccad14e', 'from_indra_statement')
# Annotation(APOE_deactivates_LDL_oxidation_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_LDL_oxidation_activity, 'LDL_oxidation', 'rule_has_object')
# Annotation(APOE_deactivates_LDL_oxidation_activity, 'a9c5c6f1-05ba-4964-afbf-b14d4806ac81', 'from_indra_statement')
# Annotation(APOE_deactivates_mitotic_S_phase_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_mitotic_S_phase_activity, 'mitotic_S_phase', 'rule_has_object')
# Annotation(APOE_deactivates_mitotic_S_phase_activity, '27908a5e-5311-43d6-9a76-c87c8f50b0b7', 'from_indra_statement')
# Annotation(APOE_deactivates_cell_cycle_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_cell_cycle_activity, 'cell_cycle', 'rule_has_object')
# Annotation(APOE_deactivates_cell_cycle_activity, 'f752d13e-2a93-4e2a-9b8c-e8171071ff09', 'from_indra_statement')
# Annotation(APOE_deactivates_cell_population_proliferation_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_cell_population_proliferation_activity, 'cell_population_proliferation', 'rule_has_object')
# Annotation(APOE_deactivates_cell_population_proliferation_activity, '22c971d6-1a1b-4fa4-8e6d-1da394a258e8', 'from_indra_statement')
# Annotation(APOE_deactivates_endothelial_cell_activation_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_endothelial_cell_activation_activity, 'endothelial_cell_activation', 'rule_has_object')
# Annotation(APOE_deactivates_endothelial_cell_activation_activity, '953a0355-c4de-473f-aa34-dc7a91376afe', 'from_indra_statement')
# Annotation(APOE_deactivates_Atherosclerosis_activity, 'APOE', 'rule_has_subject')
# Annotation(APOE_deactivates_Atherosclerosis_activity, 'Atherosclerosis', 'rule_has_object')
# Annotation(APOE_deactivates_Atherosclerosis_activity, '8a6b455a-56ea-4254-a119-ce2e1582817c', 'from_indra_statement')
# Annotation(CSNK2A1_phosphorylation_APOE_S314, 'CSNK2A1', 'rule_has_subject')
# Annotation(CSNK2A1_phosphorylation_APOE_S314, 'APOE', 'rule_has_object')
# Annotation(CSNK2A1_phosphorylation_APOE_S314, '2c21b100-3615-472a-97db-e7c67799a5bb', 'from_indra_statement')
# '<?xml version="1.0" encoding="UTF-8"?>\n<sbml xmlns="http://www.sbml.org/sbml/level3/version2/core" level="3" version="2">\n  <model name="indra_model">\n    <listOfCompartments>\n      <compartment id="default" spatialDimensions="3" size="1" constant="true"/>\n    </listOfCompartments>\n    <listOfSpecies>\n      <species id="__s0" name="LSR(apolipoprotein=None)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s1" name="AD(activity=&apos;inactive&apos;)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s2" name="APOE(lsr=None, lrp1=None, activity=&apos;inactive&apos;, S314=&apos;u&apos;)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s3" name="tumor_cell_invasion(activity=&apos;inactive&apos;)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s4" name="endocytosis(activity=&apos;inactive&apos;)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s5" name="cell_cycle(activity=&apos;inactive&apos;)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s6" name="LRP1(apolipoprotein=None)" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s7" name="Oxidized_High_Density_Lipoprotein()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s8" name="hsa_miR_1908_5p()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s9" name="hsa_miR_199a_3p()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s10" name="hsa_miR_199a_5p()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s11" name="zearalenone()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s12" name="VEGFA()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s13" name="disodium_selenite_pentahydrate()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s14" name="PON2()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s15" name="tyrphostin_B42()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s16" name="meclocycline()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s17" name="lanatoside_C()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s18" name="ethylisopropylamiloride()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s19" name="JQ1()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s20" name="all_trans_retinoic_acid()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s21" name="CHRM2()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s22" name="MT2A()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant="false"/>\n      <species id="__s23" name="hexadecanoic_acid()" compartment="default" hasOnlySubstanceUnits="true" boundaryCondition="false" constant= ...
